# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns

import sweetviz as sv

# %% [markdown]
# ## Loading data

# %%
file_path = './analytics_test_ms_1.xlsx'

df = pd.read_excel(file_path, sheet_name='total_merged', index_col=0)

df.head()
# Out:
#              country  merchant_id selling_date selling_week payment_date  \
# car_id_sales
# 3421775349        ES          NaN   2021-04-29      2021-17   2021-05-14
# 5096178328        DE    7833165.0   2021-07-13      2021-28   2021-07-19
# 5316743932        DE          NaN   2021-08-06      2021-31   2021-08-17
# 7525691980        DE          NaN   2021-06-15      2021-24   2021-06-21
# 5785159431        FR          NaN   2021-06-03      2021-22   2021-06-08
#
#               sell_price  transport_to_merchant transport_date  has_tuning  \
# car_id_sales
# 3421775349          1098                      1     2021-05-31           1
# 5096178328         15490                      0            NaT           1
# 5316743932           435                      1     2021-08-31           0
# 7525691980          2721                      1     2021-06-28           1
# 5785159431         11028                      0            NaT           0
#
#               has_airbags  ...  gear_type  ac_type  xenon_light  \
# car_id_sales               ...
# 3421775349              1  ...       1138     1050            0
# 5096178328              1  ...       1141     1049            0
# 5316743932              1  ...       1138        0            0
# 7525691980              1  ...       1139     1050            0
# 5785159431              1  ...       1138     1050            0
#
#               navigation_system  radio_system  claim_number  full_refunds  \
# car_id_sales
# 3421775349                    0        3534.0           NaN             0
# 5096178328                 1100        3534.0     C1AA16434             0
# 5316743932                    0           NaN           NaN             0
# 7525691980                    0           NaN           NaN             0
# 5785159431                 1100        3534.0           NaN             0
#
#              partial_refunds  voucher_amount  claim_status
# car_id_sales
# 3421775349                 0             NaN           NaN
# 5096178328                 0             NaN       CREATED
# 5316743932                 0             NaN           NaN
# 7525691980                 0             NaN           NaN
# 5785159431                 0             NaN           NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Dataset

# %%
df_total = df.copy()

# %%
df_total.head()
# Out:
#              country  merchant_id selling_date selling_week payment_date  \
# car_id_sales
# 3421775349        ES          NaN   2021-04-29      2021-17   2021-05-14
# 5096178328        DE    7833165.0   2021-07-13      2021-28   2021-07-19
# 5316743932        DE          NaN   2021-08-06      2021-31   2021-08-17
# 7525691980        DE          NaN   2021-06-15      2021-24   2021-06-21
# 5785159431        FR          NaN   2021-06-03      2021-22   2021-06-08
#
#               sell_price  transport_to_merchant transport_date  has_tuning  \
# car_id_sales
# 3421775349          1098                      1     2021-05-31           1
# 5096178328         15490                      0            NaT           1
# 5316743932           435                      1     2021-08-31           0
# 7525691980          2721                      1     2021-06-28           1
# 5785159431         11028                      0            NaT           0
#
#               has_airbags  ...  gear_type  ac_type  xenon_light  \
# car_id_sales               ...
# 3421775349              1  ...       1138     1050            0
# 5096178328              1  ...       1141     1049            0
# 5316743932              1  ...       1138        0            0
# 7525691980              1  ...       1139     1050            0
# 5785159431              1  ...       1138     1050            0
#
#               navigation_system  radio_system  claim_number  full_refunds  \
# car_id_sales
# 3421775349                    0        3534.0           NaN             0
# 5096178328                 1100        3534.0     C1AA16434             0
# 5316743932                    0           NaN           NaN             0
# 7525691980                    0           NaN           NaN             0
# 5785159431                 1100        3534.0           NaN             0
#
#              partial_refunds  voucher_amount  claim_status
# car_id_sales
# 3421775349                 0             NaN           NaN
# 5096178328                 0             NaN       CREATED
# 5316743932                 0             NaN           NaN
# 7525691980                 0             NaN           NaN
# 5785159431                 0             NaN           NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Definition of target column - claim "yes" (1 / 0 ) column

# %% [markdown]
# ### Recognition of claims that had complaint processing to the end and were not fully rejected. Those considered as current plaints were excluded from the dataset.

# %%
df_total['target_claim'] = df_total.apply(lambda row: 1 if (row['full_refunds'] == 1 or row['partial_refunds'] == 1) and row['claim_status'] != 'REJECTED' else 0, axis=1)

# %%
condition = (df_total['claim_number'].notnull()) & (df_total['full_refunds'] == 0) & (df_total['partial_refunds'] == 0)

# %%
rows_to_drop = df_total.loc[condition].index

# Usuń wybrane wiersze
df_total.drop(rows_to_drop, inplace=True)

# %%
df_total['target_claim'].value_counts()
# Out:
# target_claim
# 0    55152
# 1    11237
# Name: count, dtype: int64

# %% [markdown]
# ## Variables preprocessing - transforming some variables and adjusting data type

# %%
df_total['days_between_payment_and_selling'] = (df_total['payment_date'] - df_total['selling_date']).dt.days

# %%
df_total['days_between_payment_and_selling'].value_counts()
# Out:
# days_between_payment_and_selling
# 1      13218
# 2      11451
# 3       9090
# 4       8070
# 5       5219
#        ...
# 162        1
# 168        1
# 54         1
# 57         1
# 130        1
# Name: count, Length: 103, dtype: int64

# %%
x = df_total[['days_between_payment_and_selling']]

# %%
kmeans = KMeans(n_clusters=6, random_state=42)
df_total['d_payment_and_selling_clustered'] = kmeans.fit_predict(x)
# Out:
# c:\Users\marsr\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_3_index = df_total[df_total['d_payment_and_selling_clustered'] == 3].index
cluster_5_index = df_total[df_total['d_payment_and_selling_clustered'] == 5].index

df_total.loc[cluster_3_index, 'd_payment_and_selling_clustered'] = 4
df_total.loc[cluster_5_index, 'd_payment_and_selling_clustered'] = 4

# %%
df_total['d_payment_and_selling_clustered'].value_counts()
# Out:
# d_payment_and_selling_clustered
# 1    36347
# 2    22819
# 0     6350
# 4      873
# Name: count, dtype: int64

# %%
df_total['selling_week_number'] = df_total['selling_week'].str.split('-').str[1].astype(pd.Int32Dtype())

# %%
df_total['radio_system'].fillna(0, inplace=True)

# %%
df_total['radio_system'].astype(pd.Int32Dtype())
# Out:
# car_id_sales
# 3421775349    3534
# 5316743932       0
# 7525691980       0
# 5785159431    3534
# 1879501444    3534
#               ...
# 9115994556    3534
# 2548116105    1100
# 9754393407    3534
# 1548066157    3534
# 4594928165    3534
# Name: radio_system, Length: 66389, dtype: Int32

# %%
columns_to_drop = ['merchant_id', 'selling_date', 'selling_week', 'payment_date', 
                   'transport_date', 'claim_number', 'full_refunds', 
                   'partial_refunds', 'voucher_amount', 'claim_status', 'days_between_payment_and_selling']

# %%
df_total.drop(columns=columns_to_drop, inplace=True)

# %%
df_total['country'] = df_total['country'].astype('category')
df_total['radio_system'] = df_total['radio_system'].astype('int')

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66389 entries, 3421775349 to 4594928165
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          66389 non-null  category
#  1   sell_price                       66389 non-null  int64
#  2   transport_to_merchant            66389 non-null  int64
#  3   has_tuning                       66389 non-null  int64
#  4   has_airbags                      66389 non-null  int64
#  5   has_alarm_system                 66389 non-null  int64
#  6   fuel_type                        66389 non-null  int64
#  7   gear_type                        66389 non-null  int64
#  8   ac_type                          66389 non-null  int64
#  9   xenon_light                      66389 non-null  int64
#  10  navigation_system                66389 non-null  int64
#  11  radio_system                     66389 non-null  int32
#  12  target_claim                     66389 non-null  int64
#  13  d_payment_and_selling_clustered  66389 non-null  int32
#  14  selling_week_number              66389 non-null  Int32
# dtypes: Int32(1), category(1), int32(2), int64(11)
# memory usage: 9.0 MB

# %%
df_total.describe()
# Out:
#           sell_price  transport_to_merchant    has_tuning   has_airbags  \
# count   66389.000000           66389.000000  66389.000000  66389.000000
# mean     7332.026043               0.508217      0.369579      0.847806
# std      8399.883190               0.499936      0.482694      0.359211
# min         5.000000               0.000000      0.000000      0.000000
# 25%      2215.000000               0.000000      0.000000      1.000000
# 50%      4749.000000               1.000000      0.000000      1.000000
# 75%      9317.000000               1.000000      1.000000      1.000000
# max    173000.000000               1.000000      1.000000      1.000000
#
#        has_alarm_system     fuel_type     gear_type       ac_type  \
# count      66389.000000  66389.000000  66389.000000  66389.000000
# mean           0.159108   1011.640347   1138.874904    850.400428
# std            0.365779    168.159197      1.243893    411.630982
# min            0.000000      0.000000   1138.000000      0.000000
# 25%            0.000000   1039.000000   1138.000000   1049.000000
# 50%            0.000000   1040.000000   1138.000000   1050.000000
# 75%            0.000000   1040.000000   1139.000000   1050.000000
# max            1.000000   1040.000000   1141.000000   1050.000000
#
#         xenon_light  navigation_system  radio_system  target_claim  \
# count  66389.000000       66389.000000  66389.000000  66389.000000
# mean     171.742759         385.560861   1799.790116      0.169260
# std      396.906364         524.846567   1641.274055      0.374984
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      0.000000      0.000000
# 50%        0.000000           0.000000   1100.000000      0.000000
# 75%        0.000000        1100.000000   3534.000000      0.000000
# max     1089.000000        1100.000000   3534.000000      1.000000
#
#        d_payment_and_selling_clustered  selling_week_number
# count                     66389.000000              66389.0
# mean                          1.287518            21.633433
# std                           0.689241              9.09402
# min                           0.000000                  3.0
# 25%                           1.000000                 14.0
# 50%                           1.000000                 22.0
# 75%                           2.000000                 29.0
# max                           4.000000                 38.0

# %% [markdown]
# ## Visualizations of pairs: variables and target_claim (using sweetviz library)

# %%
import sweetviz as sv

report = sv.analyze(df_total, target_feat='target_claim')

report.show_html('sweetviz_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       1 import sweetviz as sv
#       3 # Generowanie raportu Sweetviz
# ----> 4 report = sv.analyze(df_total, target_feat='target_claim')
#       6 # Zapis raportu do pliku HTML
#       7 report.show_html('sweetviz_report.html')
#
# File c:\Users\marsr\anaconda3\lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# File c:\Users\marsr\anaconda3\lib\site-packages\sweetviz\dataframe_report.py:301, in DataframeReport.__init__(self, source, target_feature_name, compare, pairwise_analysis, fc, verbosity)
#     299 self.progress_bar.reset(total=len(features_to_process))
#     300 self.progress_bar.set_description_str("[Step 2/3] Processing Pairwise Features")
# --> 301 self.process_associations(features_to_process, source_target_series, compare_target_series)
#     303 self.progress_bar.reset(total=1)
#     304 self.progress_bar.set_description_str("[Step 3/3] Generating associations graph")
#
# File c:\Users\marsr\anaconda3\lib\site-packages\sweetviz\dataframe_report.py:488, in DataframeReport.process_associations(self, features_to_process, source_target_series, compare_target_series)
#     484 if self[other.source.name]["type"] == FeatureType.TYPE_NUM:
#     485     # NUM-NUM
#     486     try:
#     487         cur_associations[other.source.name] = \
# --> 488             feature.source.corr(other.source, method='pearson')
#     489     except FloatingPointError:
#     490         # This usually happens when there is only 1 non-NaN value in each data series
#     491         # Assigning the value 1.0 as per
#     492         # https://stats.stackexchange.com/questions/94150/why-is-the-pearson-correlation-1-when-only-two-data-values-are-available
#     493         # -> Also showing a warning
#     494         cur_associations[other.source.name] = 1.0
#
# File c:\Users\marsr\anaconda3\lib\site-packages\pandas\core\series.py:2727, in Series.corr(self, other, method, min_periods)
#    2724     return np.nan
#    2726 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2727     return nanops.nancorr(
#    2728         this.values, other.values, method=method, min_periods=min_periods
#    2729     )
#    2731 raise ValueError(
#    2732     "method must be either 'pearson', "
#    2733     "'spearman', 'kendall', or a callable, "
#    2734     f"'{method}' was supplied"
#    2735 )
#
# File c:\Users\marsr\anaconda3\lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Users\marsr\anaconda3\lib\site-packages\pandas\core\nanops.py:1614, in nancorr(a, b, method, min_periods)
#    1611     return np.nan
#    1613 f = get_corr_func(method)
# -> 1614 return f(a, b)
#
# File c:\Users\marsr\anaconda3\lib\site-packages\pandas\core\nanops.py:1637, in get_corr_func.<locals>.func(a, b)
#    1636 def func(a, b):
# -> 1637     return np.corrcoef(a, b)[0, 1]
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File c:\Users\marsr\anaconda3\lib\site-packages\numpy\lib\function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File c:\Users\marsr\anaconda3\lib\site-packages\numpy\lib\function_base.py:2681, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2678     else:
#    2679         w *= aweights
# -> 2681 avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2682 w_sum = w_sum[0]
#    2684 # Determine the normalization
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File c:\Users\marsr\anaconda3\lib\site-packages\numpy\lib\function_base.py:555, in average(a, axis, weights, returned, keepdims)
#     551     avg = avg_as_array = np.multiply(a, wgt,
#     552                       dtype=result_dtype).sum(axis, **keepdims_kw) / scl
#     554 if returned:
# --> 555     if scl.shape != avg_as_array.shape:
#     556         scl = np.broadcast_to(scl, avg_as_array.shape).copy()
#     557     return avg, scl
#
# AttributeError: 'float' object has no attribute 'shape'
